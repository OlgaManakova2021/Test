# %% [markdown]
# <a href="https://colab.research.google.com/github/OlgaManakova2021/Test/blob/main/test2/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([1, 2, 3, 4])
y = np.array([i**2 for i in x])
plt.plot(x, y)
plt.show()

# %%
plt.subplot(1, 3, 1)
plt.plot(np.random.random(10))
plt.subplot(1, 3, 2)
plt.plot(x, y)
plt.subplot(1, 3, 3)
plt.plot(x, y)
plt.show()
